# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.layers as layers
from tensorflow.keras.models import save_model

# %%
# MNISTデータロード
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
# 1行に並べて正規化
x_train = x_train.astype(np.float32).reshape(-1, 784) / 255.0
x_test = x_test.astype(np.float32).reshape(-1, 784) / 255.0

# %%
# 多層パーセプトロン(MLP)構築
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((784, )),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# モデル可視化
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    '01_mlp_mnist.hdf5', verbose=1, save_weights_only=False)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# 訓練
model.fit(
    x_train,
    y_train,
    epochs=15,
    batch_size=128,
    validation_data=(x_test, y_test),
    callbacks=[cp_callback]
)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/15
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.3371 - accuracy: 0.9042
# Epoch 00001: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.3366 - accuracy: 0.9044 - val_loss: 0.1651 - val_accuracy: 0.9520
# Epoch 2/15
# 57728/60000 [===========================>..] - ETA: 0s - loss: 0.1310 - accuracy: 0.9615
# Epoch 00002: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.1307 - accuracy: 0.9616 - val_loss: 0.1152 - val_accuracy: 0.9672
# Epoch 3/15
# 57856/60000 [===========================>..] - ETA: 0s - loss: 0.0911 - accuracy: 0.9731
# Epoch 00003: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 1s 25us/sample - loss: 0.0905 - accuracy: 0.9732 - val_loss: 0.1052 - val_accuracy: 0.9677
# Epoch 4/15
# 58496/60000 [============================>.] - ETA: 0s - loss: 0.0691 - accuracy: 0.9792
# Epoch 00004: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0687 - accuracy: 0.9793 - val_loss: 0.0895 - val_accuracy: 0.9715
# Epoch 5/15
# 58880/60000 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9842
# Epoch 00005: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0531 - accuracy: 0.9842 - val_loss: 0.0810 - val_accuracy: 0.9759
# Epoch 6/15
# 57984/60000 [===========================>..] - ETA: 0s - loss: 0.0438 - accuracy: 0.9864
# Epoch 00006: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0438 - accuracy: 0.9865 - val_loss: 0.0843 - val_accuracy: 0.9749
# Epoch 7/15
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9890
# Epoch 00007: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.0818 - val_accuracy: 0.9745
# Epoch 8/15
# 59264/60000 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9910
# Epoch 00008: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0301 - accuracy: 0.9910 - val_loss: 0.0774 - val_accuracy: 0.9776
# Epoch 9/15
# 59264/60000 [============================>.] - ETA: 0s - loss: 0.0256 - accuracy: 0.9923
# Epoch 00009: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0255 - accuracy: 0.9923 - val_loss: 0.0853 - val_accuracy: 0.9759
# Epoch 10/15
# 59136/60000 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9938
# Epoch 00010: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 25us/sample - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.0877 - val_accuracy: 0.9751
# Epoch 11/15
# 57984/60000 [===========================>..] - ETA: 0s - loss: 0.0171 - accuracy: 0.9951
# Epoch 00011: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0858 - val_accuracy: 0.9778
# Epoch 12/15
# 57984/60000 [===========================>..] - ETA: 0s - loss: 0.0148 - accuracy: 0.9956
# Epoch 00012: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 26us/sample - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.0841 - val_accuracy: 0.9782
# Epoch 13/15
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9968
# Epoch 00013: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0119 - accuracy: 0.9968 - val_loss: 0.0899 - val_accuracy: 0.9770
# Epoch 14/15
# 58240/60000 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9972
# Epoch 00014: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.1026 - val_accuracy: 0.9772
# Epoch 15/15
# 57600/60000 [===========================>..] - ETA: 0s - loss: 0.0121 - accuracy: 0.9963
# Epoch 00015: saving model to 01_mlp_mnist.hdf5
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0921 - val_accuracy: 0.9774

# %%
# モデル評価
val_loss, val_acc = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
# 保存したモデルのロード
load_model = tf.keras.models.load_model("01_mlp_mnist.hdf5")

# %%
# テスト画像を1枚ロード
from IPython.display import Image, display_png
from tensorflow.keras.preprocessing.image import img_to_array, load_img

img = tf.keras.preprocessing.image.load_img('image/03.jpg', False, target_size=(28, 28))
display_png(img)

# %%
# 入力画像成形、および正規化
x = img.convert('L')
x = img_to_array(x)
x = x.reshape(-1, 784)
x = x.astype('float32')
x /= 255

# %%
# 推論実行
predict_result = load_model.predict(x)

# %%
print(predict_result)
print(np.squeeze(predict_result)) # 不要な次元を削除
print(np.argmax(np.squeeze(predict_result)))
# Out:
# [[3.5342624e-16 7.1185800e-11 8.1469817e-11 9.9998915e-01 1.0339765e-18
#   1.0878214e-05 9.3854394e-22 1.3249675e-15 5.5499936e-12 1.3673384e-09]]
# [3.5342624e-16 7.1185800e-11 8.1469817e-11 9.9998915e-01 1.0339765e-18
#  1.0878214e-05 9.3854394e-22 1.3249675e-15 5.5499936e-12 1.3673384e-09]
# 3
